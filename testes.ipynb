# %%
#Importando a biblioteca pandas e definindo o dataframe
import pandas as pd
#from pandas.io.formats.style import Styler # É necessária a instalação da biblioteca Jinja2

df = pd.read_excel('\test_results\dados_amostra_2.xlsx')
dfcopy = df.copy()
#pd.set_option('display.max_rows', None)   # Configura para exibir todas as linhas
#pd.set_option('display.max_colwidth', None)  # Configura para exibir todo o texto das colunas
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[1], line 5
#       2 import pandas as pd
#       3 #from pandas.io.formats.style import Styler # É necessária a instalação da biblioteca Jinja2
# ----> 5 df = pd.read_excel('\test_results\dados_amostra_2.xlsx')
#       6 dfcopy = df.copy()
#       7 #pd.set_option('display.max_rows', None)   # Configura para exibir todas as linhas
#       8 #pd.set_option('display.max_colwidth', None)  # Configura para exibir todo o texto das colunas
#
# File c:\data_extraction\env\Lib\site-packages\pandas\io\excel\_base.py:478, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend)
# ...

# %%
df_orientador = df.drop(['CONTEUDO', 'RESUMO', 'ABSTRACT'], axis = 1)
df_orientador = df_orientador.sort_values('ORIENTADOR')
#df_orientador

# %%
df.shape
# Out:
# (100, 8)

# %%
print(df.iloc[73,0])
print(df.iloc[73,1])
print(df.iloc[73,2])
print(df.iloc[73,3])
print(df.iloc[73,4])
print(df.iloc[73,5])
print(df.iloc[73,6])
print(df.iloc[73,7])
# Out:
# metadata\dissertacao_0074.txt
# ...

# %%
df.iloc[73,2]

# %%
df.iloc[73,3]

# %%
df.iloc[73,4]

# %%
df.iloc[73,5]

# %%
df.iloc[73,6]
